# %%
import pandas as pd

# %%
path = "C:\\Users\\millen11\\Dropbox\\PC\\Documents\\academia\\rpi\\classes\\fall23\\introToML\\"
ps_df = pd.read_csv(path + "global_socieoeconomic_df.csv")
display(ps_df)
# Out:
#                Open         High          Low        Close    Volume
# 0       3129.573975  3130.112061  3101.756104  3109.104980    101200  \
# 1       3129.573975  3130.112061  3101.756104  3109.104980    101200
# 2       3129.573975  3130.112061  3101.756104  3109.104980    101200
# 3       3129.573975  3130.112061  3101.756104  3109.104980    101200
# 4       3129.573975  3130.112061  3101.756104  3109.104980    101200
# ...             ...          ...          ...          ...       ...
# 377849  2007.459961  2016.790039  2006.040039  2012.199951  45498400
# 377850  2007.459961  2016.790039  2006.040039  2012.199951  45498400
# 377851  2007.459961  2016.790039  2006.040039  2012.199951  45498400
# 377852  2007.459961  2016.790039  2006.040039  2012.199951  45498400
# 377853  2007.459961  2016.790039  2006.040039  2012.199951  45498400
#
#         Change In Price (%)   ECPI   CCPI  GSCPI      EPSI  ...
# 0                 -0.654050   93.8   90.2   0.39  2.725238  ...  \
# 1                 -0.654050   92.1   91.6   0.39  2.701171  ...
# 2                 -0.654050   12.4   98.5   0.39  2.633433  ...
# 3                 -0.654050   90.0   91.9   0.39  2.588454  ...
# 4                 -0.654050  104.4  101.4   0.39  3.141094  ...
# ...                     ...    ...    ...    ...       ...  ...
# 377849             0.236119  137.9  121.9   1.78  2.613156  ...
# 377850             0.236119  697.0  308.3   1.78  2.614502  ...
# 377851             0.236119  160.4  122.0   1.78  2.468536  ...
# 377852             0.236119  112.2  121.1   1.78  2.607859  ...
# 377853             0.236119  202.8  134.1   1.78  1.628675  ...
#
#         Country_Taiwan, China  Country_Tanzania, United Rep.
# 0                       False                          False  \
# 1                       False                          False
# 2                       False                          False
# 3                       False                          False
# 4                       False                          False
# ...                       ...                            ...
# 377849                  False                          False
# 377850                  False                          False
# 377851                  False                          False
# 377852                  False                          False
# 377853                  False                          False
#
#         Country_Thailand  Country_Trinidad and Tobago  Country_Turkey
# 0                  False                        False           False  \
# 1                  False                        False           False
# 2                  False                        False           False
# 3                  False                        False           False
# 4                  False                        False           False
# ...                  ...                          ...             ...
# 377849             False                        False           False
# 377850             False                        False           False
# 377851             False                        False           False
# 377852             False                        False           False
# 377853             False                        False           False
#
#         Country_Türkiye  Country_Uganda  Country_Ukraine
# 0                 False           False            False  \
# 1                 False           False            False
# 2                 False           False            False
# 3                 False           False            False
# 4                 False           False            False
# ...                 ...             ...              ...
# 377849            False            True            False
# 377850            False           False             True
# 377851            False           False            False
# 377852            False           False            False
# 377853            False           False            False
#
#         Country_United Kingdom  Country_United States
# 0                        False                  False
# 1                        False                  False
# 2                        False                  False
# 3                        False                  False
# 4                        False                  False
# ...                        ...                    ...
# 377849                   False                  False
# 377850                   False                  False
# 377851                   False                   True
# 377852                   False                  False
# 377853                   False                  False
#
# [377854 rows x 220 columns]

# %%
#PS1: Do external factors affect the stock market, if so, how much is performance affected?
covid_df = pd.read_csv(path + "covid_df.csv")
covid_df = covid_df.drop(columns = ["Unnamed: 0"])
display(covid_df)

mean_price_change_covid_df = covid_df["Change In Price (%)"].mean()
# print(mean_price_change_covid_df)

non_covid_df = pd.read_csv(path + "non_covid_df.csv")
non_covid_df = non_covid_df.drop(columns = ["Unnamed: 0"])
display(non_covid_df)
mean_price_change_nonCovid_df = non_covid_df["Change In Price (%)"].mean()
# print(mean_price_change_nonCovid_df)

russia_ukraine_df = pd.read_csv(path + "russia_ukraine_df.csv")
russia_ukraine_df = russia_ukraine_df.drop(columns = ["Unnamed: 0"])
display(russia_ukraine_df)

mean_price_change_ru_df = russia_ukraine_df["Change In Price (%)"].mean()
# print(mean_price_change_ru_df)

non_russia_ukraine_df = pd.read_csv(path + "non_russia_ukraine_df.csv")
non_russia_ukraine_df = non_russia_ukraine_df.drop(columns = ["Unnamed: 0"])
display(non_russia_ukraine_df)
mean_price_change_nonRU_df = non_russia_ukraine_df["Change In Price (%)"].mean()
# print(mean_price_change_nonRU_df)
# Out:
#             Country        Date   ECPI   CCPI  GSCPI      EPSI          Open
# 0            Greece  2020-01-31  105.7   98.9   0.09  6.000000   3133.399902  \
# 1            Greece  2020-01-31  105.7   98.9   0.09  6.000000   7108.600098
# 2            Greece  2020-01-31  105.7   98.9   0.09  6.000000   7008.399902
# 3            Greece  2020-01-31  105.7   98.9   0.09  6.000000   3938.800049
# 4            Greece  2020-01-31  105.7   98.9   0.09  6.000000  41146.558594
# ...             ...         ...    ...    ...    ...       ...           ...
# 87774  South Africa  2023-03-31  186.5  138.7  -1.18  1.639814   1775.050049
# 87775  South Africa  2023-03-31  186.5  138.7  -1.18  1.639814   3265.010010
# 87776  South Africa  2023-03-31  186.5  138.7  -1.18  1.639814   4285.839844
# 87777  South Africa  2023-03-31  186.5  138.7  -1.18  1.639814  15874.190430
# 87778  South Africa  2023-03-31  186.5  138.7  -1.18  1.639814     19.209999
#
#                High           Low         Close      Volume
# 0       3143.290039   3076.649902   3076.649902           0  \
# 1       7147.600098   7108.600098   7121.200195  1011496700
# 2       7046.700195   7008.399902   7017.200195      756400
# 3       3952.530029   3901.580078   3907.610107    26161100
# 4      41154.488281  40671.011719  40723.488281       11500
# ...             ...           ...           ...         ...
# 87774   1802.699951   1775.050049   1802.479980  4525120000
# 87775   3273.469971   3255.590088   3258.899902   333549200
# 87776   4325.339844   4278.310059   4315.049805    36312200
# 87777  15951.799805  15857.190430  15868.059570     2440300
# 87778     19.430000     18.520000     18.700001           0
#
#                   Region  Change In Price (%) Month Day of Week
# 0                    NaN            -1.811132   Jan      Friday
# 1                    NaN             0.177251   Jan      Friday
# 2        ASEAN & Oceania             0.125568   Jan      Friday
# 3                 Europe            -0.791864   Jan      Friday
# 4      South & West Asia            -1.028203   Jan      Friday
# ...                  ...                  ...   ...         ...
# 87774        US & Canada             1.545305   Mar      Friday
# 87775    ASEAN & Oceania            -0.187139   Mar      Friday
# 87776             Europe             0.681546   Mar      Friday
# 87777          East Asia            -0.038622   Mar      Friday
# 87778                NaN            -2.654859   Mar      Friday
#
# [87779 rows x 15 columns]
#              Country        Date   ECPI   CCPI  GSCPI      EPSI          Open
# 0             Greece  2011-01-31   89.5  102.8   0.81  6.000000   2751.527100  \
# 1             Greece  2011-01-31   89.5  102.8   0.81  6.000000  11884.207285
# 2             Greece  2011-01-31   89.5  102.8   0.81  6.000000   4857.600098
# 3             Greece  2011-01-31   89.5  102.8   0.81  6.000000   4757.899902
# 4             Greece  2011-01-31   89.5  102.8   0.81  6.000000   2636.649902
# ...              ...         ...    ...    ...    ...       ...           ...
# 306590  South Africa  2019-10-31  135.1  120.6   0.09  1.663302   3217.600098
# 306591  South Africa  2019-10-31  135.1  120.6   0.09  1.663302   3625.360107
# 306592  South Africa  2019-10-31  135.1  120.6   0.09  1.663302   1577.239990
# 306593  South Africa  2019-10-31  135.1  120.6   0.09  1.663302  11393.679688
# 306594  South Africa  2019-10-31  135.1  120.6   0.09  1.663302     13.510000
#
#                 High           Low         Close     Volume
# 0        2790.920898   2748.538086   2790.694092      91600  \
# 1       12020.375688  11820.068352  11994.545898      62000
# 2        4857.600098   4816.100098   4850.000000  990059600
# 3        4758.100098   4717.600098   4753.899902          0
# 4        2649.939941   2621.530029   2638.699951   27563000
# ...              ...           ...           ...        ...
# 306590   3235.239990   3213.459961   3229.879883  302617400
# 306591   3631.870117   3593.600098   3604.409912   44941700
# 306592   1584.810059   1571.770020   1577.969971   83413300
# 306593  11428.419922  11358.709961  11358.709961    2507400
# 306594     13.950000     13.180000     13.220000          0
#
#                    Region  Change In Price (%) Month Day of Week
# 0               East Asia             1.423464   Jan      Monday
# 1               East Asia             0.928447   Jan      Monday
# 2                     NaN            -0.156458   Jan      Monday
# 3         ASEAN & Oceania            -0.084071   Jan      Monday
# 4                  Europe             0.077752   Jan      Monday
# ...                   ...                  ...   ...         ...
# 306590    ASEAN & Oceania             0.381644   Oct    Thursday
# 306591             Europe            -0.577879   Oct    Thursday
# 306592  South & West Asia             0.046282   Oct    Thursday
# 306593          East Asia            -0.306922   Oct    Thursday
# 306594                NaN            -2.146558   Oct    Thursday
#
# [306595 rows x 15 columns]
#             Country        Date   ECPI   CCPI  GSCPI      EPSI          Open
# 0           Albania  2022-02-28  113.2  103.1   2.74  2.646495   3450.320068  \
# 1           Albania  2022-02-28  113.2  103.1   2.74  2.646495  13397.929688
# 2           Albania  2022-02-28  113.2  103.1   2.74  2.646495   7273.700195
# 3           Albania  2022-02-28  113.2  103.1   2.74  2.646495   7022.200195
# 4           Albania  2022-02-28  113.2  103.1   2.74  2.646495   3983.610107
# ...             ...         ...    ...    ...    ...       ...           ...
# 28290  South Africa  2023-03-31  186.5  138.7  -1.18  1.639814   1775.050049
# 28291  South Africa  2023-03-31  186.5  138.7  -1.18  1.639814   3265.010010
# 28292  South Africa  2023-03-31  186.5  138.7  -1.18  1.639814   4285.839844
# 28293  South Africa  2023-03-31  186.5  138.7  -1.18  1.639814  15874.190430
# 28294  South Africa  2023-03-31  186.5  138.7  -1.18  1.639814     19.209999
#
#                High           Low         Close      Volume           Region
# 0       3462.310059   3425.520020   3462.310059      345800        East Asia  \
# 1      13457.610352  13279.320312  13455.730469     1246000        East Asia
# 2       7323.700195   7249.399902   7323.200195  1454099500              NaN
# 3       7049.600098   6979.399902   7049.100098     1007600  ASEAN & Oceania
# 4       4019.419922   3974.669922   4014.020020       21400           Europe
# ...             ...           ...           ...         ...              ...
# 28290   1802.699951   1775.050049   1802.479980  4525120000      US & Canada
# 28291   3273.469971   3255.590088   3258.899902   333549200  ASEAN & Oceania
# 28292   4325.339844   4278.310059   4315.049805    36312200           Europe
# 28293  15951.799805  15857.190430  15868.059570     2440300        East Asia
# 28294     19.430000     18.520000     18.700001           0              NaN
#
#        Change In Price (%) Month Day of Week
# 0                 0.347504   Feb      Monday
# 1                 0.431416   Feb      Monday
# 2                 0.680534   Feb      Monday
# 3                 0.383069   Feb      Monday
# 4                 0.763376   Feb      Monday
# ...                    ...   ...         ...
# 28290             1.545305   Mar      Friday
# 28291            -0.187139   Mar      Friday
# 28292             0.681546   Mar      Friday
# 28293            -0.038622   Mar      Friday
# 28294            -2.654859   Mar      Friday
#
# [28295 rows x 15 columns]
#              Country        Date   ECPI   CCPI  GSCPI      EPSI          Open
# 0             Greece  2011-01-31   89.5  102.8   0.81  6.000000   2751.527100  \
# 1             Greece  2011-01-31   89.5  102.8   0.81  6.000000  11884.207285
# 2             Greece  2011-01-31   89.5  102.8   0.81  6.000000   4857.600098
# 3             Greece  2011-01-31   89.5  102.8   0.81  6.000000   4757.899902
# 4             Greece  2011-01-31   89.5  102.8   0.81  6.000000   2636.649902
# ...              ...         ...    ...    ...    ...       ...           ...
# 366074  South Africa  2022-01-31  163.1  129.7   3.59  1.633637   1968.089966
# 366075  South Africa  2022-01-31  163.1  129.7   3.59  1.633637   3250.550049
# 366076  South Africa  2022-01-31  163.1  129.7   3.59  1.633637   4161.770020
# 366077  South Africa  2022-01-31  163.1  129.7   3.59  1.633637   2033.469971
# 366078  South Africa  2022-01-31  163.1  129.7   3.59  1.633637     28.360001
#
#                 High           Low         Close      Volume
# 0        2790.920898   2748.538086   2790.694092       91600  \
# 1       12020.375688  11820.068352  11994.545898       62000
# 2        4857.600098   4816.100098   4850.000000   990059600
# 3        4758.100098   4717.600098   4753.899902           0
# 4        2649.939941   2621.530029   2638.699951    27563000
# ...              ...           ...           ...         ...
# 366074   2028.449951   1960.109985   2028.449951  5098610000
# 366075   3276.310059   3245.669922   3249.590088   192341700
# 366076   4200.830078   4134.069824   4174.600098    39621200
# 366077   2040.489990   2000.390015   2029.479980    93521700
# 366078     29.410000     24.709999     24.830000           0
#
#                    Region  Change In Price (%) Month Day of Week
# 0               East Asia             1.423464   Jan      Monday
# 1               East Asia             0.928447   Jan      Monday
# 2                     NaN            -0.156458   Jan      Monday
# 3         ASEAN & Oceania            -0.084071   Jan      Monday
# 4                  Europe             0.077752   Jan      Monday
# ...                   ...                  ...   ...         ...
# 366074        US & Canada             3.066932   Jan      Monday
# 366075    ASEAN & Oceania            -0.029532   Jan      Monday
# 366076             Europe             0.308284   Jan      Monday
# 366077  South & West Asia            -0.196216   Jan      Monday
# 366078                NaN           -12.447111   Jan      Monday
#
# [366079 rows x 15 columns]

# %%
print("COVID Change in Price: {:.2f}", mean_price_change_covid_df * 100)
print("NON-COVID Change in Price: {:.2f}", mean_price_change_nonCovid_df * 100)
print("Russia-Ukraine War Change in Price: {:.2f}", mean_price_change_ru_df * 100)
print("Non-Russia-Ukraine War Change in Price: {:.2f}",mean_price_change_nonRU_df * 100)
# Out:
# COVID Change in Price: {:.2f} -27.686875076621686
# NON-COVID Change in Price: {:.2f} 1.7503421597832862
# Russia-Ukraine War Change in Price: {:.2f} -18.38060365371628
# Non-Russia-Ukraine War Change in Price: {:.2f} -3.7521979476837384

# %%
'''
As displayed by the above changes in price, the market is clearly affected by external factors--in this case COVID and/or the Russia-Ukraine War.
In fact, it seems the daily return is affected at least 14 percent in these times.
'''
# Out:
# '\nAs displayed by the above changes in price, the market is clearly affected by external factors--in this case COVID and/or the Russia-Ukraine War.\nIn fact, it seems the daily return is affected at least 14 percent in these times.\n'

# %%
#PS2: Are the stock prices an indicator of the environment?
'''
Model Selection:
  Models to be tested and/or selected--
    * Decision Tree Classifier
    * Gradient Boosting Classifier
    * LightGBM
    * Logistic Regression
    * RandomForest Classifier
    * MLP Classifier
    * SVM
    * KNN Classifier
'''
#Model imports
from lightgbm import LGBMClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
def evaluate_model(y_test, y_pred): #Gives evaluation metrics for model
  acc_score = accuracy_score(y_test, y_pred)
  class_report = classification_report(y_test, y_pred)
  print("Accuracy Score: {:.2f}", acc_score)
  print(class_report)

# %%
#Gathering data for models
event_covid_df = covid_df["Change In Price (%)"]
event_ru_df = russia_ukraine_df["Change In Price (%)"]

X_non_covid = non_covid_df.sample(n = len(event_covid_df), random_state = 1)
X_non_covid_encoded = pd.get_dummies(X_non_covid)
X_non_covid_encoded.columns = X_non_covid_encoded.columns.str.replace("[^a-zA-Z0-9]", "_")

y_covid = event_covid_df
y_covid_binary = ((y_covid > non_covid_df["Change In Price (%)"].mean()) | (y_covid < non_covid_df["Change In Price (%)"].mean())).astype(int)

X_non_ru = non_russia_ukraine_df.sample(n = len(event_ru_df), random_state = 1)
X_non_ru_encoded = pd.get_dummies(X_non_ru)
X_non_ru_encoded.columns = X_non_ru_encoded.columns.str.replace("[^a-zA-Z0-9]", "_")
y_ru = event_ru_df
y_ru_binary = ((y_ru > non_russia_ukraine_df["Change In Price (%)"].mean()) | (y_ru < non_russia_ukraine_df["Change In Price (%)"].mean())).astype(int)

X_train_covid, X_test_covid, y_train_covid, y_test_covid = train_test_split(X_non_covid_encoded, y_covid_binary, train_size = .7, random_state = 1)
X_train_ru, X_test_ru, y_train_ru, y_test_ru = train_test_split(X_non_ru_encoded, y_ru_binary, train_size = .7, random_state = 1)

# %%
#LogisticRegression
LOGR_covid = LogisticRegression().fit(X_train_covid,y_train_covid)
pred_covid = LOGR_covid.predict(X_test_covid)

LOGR_ru = LogisticRegression().fit(X_train_ru,y_train_ru)
pred_ru = LOGR_ru.predict(X_test_ru)
print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\millen11\Dropbox\PC\Documents\academia\rpi\classes\fall23\introToML\introToMLapps\project\analysis\find_socioeconomic_solutions.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> #LogisticRegression
# ----> <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> LOGR_covid = LogisticRegression().fit(X_train_covid,y_train_covid)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> pred_covid = LOGR_covid.predict(X_test_covid)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> LOGR_ru = LogisticRegression().fit(X_train_ru,y_train_ru)
#
# File c:\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1241, in LogisticRegression.fit(self, X, y, sample_weight)
#    1239 classes_ = self.classes_
#    1240 if n_classes < 2:
# -> 1241     raise ValueError(
#    1242         "This solver needs samples of at least 2 classes"
#    1243         " in the data, but the data contains only one"
#    1244         " class: %r"
#    1245         % classes_[0]
#    1246     )
#    1248 if len(self.classes_) == 2:
#    1249     n_classes = 1
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 1

# %%
#LightGBM Classifier
lightGBM_covid = LGBMClassifier().fit(X_train_covid,y_train_covid)
pred_covid = lightGBM_covid.predict(X_test_covid)

lightGBM_ru = LGBMClassifier().fit(X_train_ru,y_train_ru)
pred_ru = lightGBM_ru.predict(X_test_ru)

print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\millen11\Dropbox\PC\Documents\academia\rpi\classes\fall23\introToML\introToMLapps\project\analysis\find_socioeconomic_solutions.ipynb Cell 10 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> #LightGBM Classifier
# ----> <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> lightGBM_covid = LGBMClassifier().fit(X_train_covid,y_train_covid)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> pred_covid = lightGBM_covid.predict(X_test_covid)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> lightGBM_ru = LGBMClassifier().fit(X_train_ru,y_train_ru)
#
# File c:\Python311\Lib\site-packages\lightgbm\sklearn.py:1097, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1095 """Docstring is inherited from the LGBMModel."""
#    1096 _LGBMAssertAllFinite(y)
# -> 1097 _LGBMCheckClassificationTargets(y)
#    1098 self._le = _LGBMLabelEncoder().fit(y)
#    1099 _y = self._le.transform(y)
#
# File c:\Python311\Lib\site-packages\sklearn\utils\multiclass.py:218, in check_classification_targets(y)
#     210 y_type = type_of_target(y, input_name="y")
#     211 if y_type not in [
#     212     "binary",
#     213     "multiclass",
#    (...)
#     216     "multilabel-sequences",
#     217 ]:
# --> 218     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'

# %%
#Gradient Boosting Classifier
GB_covid = GradientBoostingClassifier().fit(X_train_covid,y_train_covid)
pred_covid = GB_covid.predict(X_test_covid)

GB_ru = GradientBoostingClassifier().fit(X_train_ru,y_train_ru)
pred_ru = GB_ru.predict(X_test_ru)
print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\millen11\Dropbox\PC\Documents\academia\rpi\classes\fall23\introToML\introToMLapps\project\analysis\find_socioeconomic_solutions.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> #Gradient Boosting Classifier
# ----> <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> GB_covid = GradientBoostingClassifier().fit(X_train_covid,y_train_covid)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> pred_covid = GB_covid.predict(X_test_covid)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> GB_ru = GradientBoostingClassifier().fit(X_train_ru,y_train_ru)
#
# File c:\Python311\Lib\site-packages\sklearn\ensemble\_gb.py:440, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     437 y = column_or_1d(y, warn=True)
#     439 if is_classifier(self):
# --> 440     y = self._validate_y(y, sample_weight)
#     441 else:
#     442     y = self._validate_y(y)
#
# File c:\Python311\Lib\site-packages\sklearn\ensemble\_gb.py:1232, in GradientBoostingClassifier._validate_y(self, y, sample_weight)
#    1230 n_trim_classes = np.count_nonzero(np.bincount(y, sample_weight))
#    1231 if n_trim_classes < 2:
# -> 1232     raise ValueError(
#    1233         "y contains %d class after sample_weight "
#    1234         "trimmed classes with zero weights, while a "
#    1235         "minimum of 2 classes are required." % n_trim_classes
#    1236     )
#    1237 self._n_classes = len(self.classes_)
#    1238 # expose n_classes_ attribute
#
# ValueError: y contains 1 class after sample_weight trimmed classes with zero weights, while a minimum of 2 classes are required.

# %%
#Random Forest Classifier
RF_covid = RandomForestClassifier().fit(X_train_covid,y_train_covid)
pred_covid = RF_covid.predict(X_test_covid)

RF_ru = RandomForestClassifier().fit(X_train_ru,y_train_ru)
pred_ru = RF_ru.predict(X_test_ru)
print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
# Out:
# Accuracy Score: {:.2f} 1.0
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     52668
#
#     accuracy                           1.00     52668
#    macro avg       1.00      1.00      1.00     52668
# weighted avg       1.00      1.00      1.00     52668
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\millen11\Dropbox\PC\Documents\academia\rpi\classes\fall23\introToML\introToMLapps\project\analysis\find_socioeconomic_solutions.ipynb Cell 12 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> RF_ru = RandomForestClassifier().fit(X_train_ru,y_train_ru)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> pred_ru = RF_ru.predict(X_test_ru)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
#MLP Classifier
scaler = StandardScaler()
X_train_covid_scaled = scaler.fit_transform(X_train_covid)
X_test_covid_scaled = scaler.fit_transform(X_test_covid)
X_train_ru_scaled = scaler.fit_transform(X_train_ru)
X_test_ru_scaled = scaler.fit_transform(X_test_ru)

MLP_covid = MLPClassifier(random_state = 1).fit(X_train_covid_scaled, y_train_covid)
pred_covid = MLP_covid.predict(X_test_covid_scaled)
MLP_ru = MLPClassifier(random_state = 1).fit(X_train_ru_scaled, y_train_ru)
pred_ru = MLP_ru.predict(X_test_ru_scaled)

print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\millen11\Dropbox\PC\Documents\academia\rpi\classes\fall23\introToML\introToMLapps\project\analysis\find_socioeconomic_solutions.ipynb Cell 13 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> X_train_ru_scaled = scaler.fit_transform(X_train_ru)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> X_test_ru_scaled = scaler.fit_transform(X_test_ru)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> MLP_covid = MLPClassifier(random_state = 1).fit(X_train_covid_scaled, y_train_covid)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> pred_covid = MLP_covid.predict(X_test_covid_scaled)
#      <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> MLP_ru = MLPClassifier(random_state = 1).fit(X_train_ru_scaled, y_train_ru)
#
# File c:\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:749, in BaseMultilayerPerceptron.fit(self, X, y)
#     731 """Fit the model to data matrix X and target(s) y.
#     732
#     733 Parameters
#    (...)
#     745     Returns a trained MLP model.
#     746 """
#     747 self._validate_params()
# --> 749 return self._fit(X, y, incremental=False)
#
# File c:\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:437, in BaseMultilayerPerceptron._fit(self, X, y, incremental)
#     430     raise ValueError(
#     431         "hidden_layer_sizes must be > 0, got %s." % hidden_layer_sizes
#     432     )
#     433 first_pass = not hasattr(self, "coefs_") or (
#     434     not self.warm_start and not incremental
#     435 )
# --> 437 X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     439 n_samples, n_features = X.shape
#     441 # Ensure y is 2D
#
# File c:\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1120, in MLPClassifier._validate_input(self, X, y, incremental, reset)
#    1118 if (not hasattr(self, "classes_")) or (not self.warm_start and not incremental):
#    1119     self._label_binarizer = LabelBinarizer()
# -> 1120     self._label_binarizer.fit(y)
#    1121     self.classes_ = self._label_binarizer.classes_
#    1122 else:
#
# File c:\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:311, in LabelBinarizer.fit(self, y)
#     308     raise ValueError("y has 0 samples: %r" % y)
#     310 self.sparse_input_ = sp.issparse(y)
# --> 311 self.classes_ = unique_labels(y)
#     312 return self
#
# File c:\Python311\Lib\site-packages\sklearn\utils\multiclass.py:107, in unique_labels(*ys)
#     105 _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#     106 if not _unique_labels:
# --> 107     raise ValueError("Unknown label type: %s" % repr(ys))
#     109 if is_array_api:
#     110     # array_api does not allow for mixed dtypes
#     111     unique_ys = xp.concat([_unique_labels(y) for y in ys])
#
# ValueError: Unknown label type: (array([ 0.24303408, -1.2099409 , -1.01390431, ..., -0.96177041,
#         0.12556779, -0.1813657 ]),)

# %%
#SVC
SVM_covid = SVC().fit(X_train_covid, y_train_covid)
pred_covid = SVM_covid.predict(X_test_covid)

SVM_ru = SVC().fit(X_train_ru, y_train_ru)
pred_ru = SVM_ru.predict(X_test_ru)

print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\millen11\Dropbox\PC\Documents\academia\rpi\classes\fall23\introToML\introToMLapps\project\analysis\find_socioeconomic_solutions.ipynb Cell 14 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> #SVC
# ----> <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> SVM_covid = SVC().fit(X_train_covid, y_train_covid)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> pred_covid = SVM_covid.predict(X_test_covid)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> SVM_ru = SVC().fit(X_train_ru, y_train_ru)
#
# File c:\Python311\Lib\site-packages\sklearn\svm\_base.py:201, in BaseLibSVM.fit(self, X, y, sample_weight)
#     191 else:
#     192     X, y = self._validate_data(
#     193         X,
#     194         y,
#    (...)
#     198         accept_large_sparse=False,
#     199     )
# --> 201 y = self._validate_targets(y)
#     203 sample_weight = np.asarray(
#     204     [] if sample_weight is None else sample_weight, dtype=np.float64
#     205 )
#     206 solver_type = LIBSVM_IMPL.index(self._impl)
#
# File c:\Python311\Lib\site-packages\sklearn\svm\_base.py:745, in BaseSVC._validate_targets(self, y)
#     743 def _validate_targets(self, y):
#     744     y_ = column_or_1d(y, warn=True)
# --> 745     check_classification_targets(y)
#     746     cls, y = np.unique(y_, return_inverse=True)
#     747     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#
# File c:\Python311\Lib\site-packages\sklearn\utils\multiclass.py:218, in check_classification_targets(y)
#     210 y_type = type_of_target(y, input_name="y")
#     211 if y_type not in [
#     212     "binary",
#     213     "multiclass",
#    (...)
#     216     "multilabel-sequences",
#     217 ]:
# --> 218     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'

# %%
#KNN Classifier
KNN_covid = KNeighborsClassifier().fit(X_train_covid, y_train_covid)
pred_covid = KNN_covid.predict(X_test_covid)

KNN_ru = KNeighborsClassifier().fit(X_train_ru, y_train_ru)
pred_ru = KNN_ru.predict(X_test_ru)

print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
# Out:
# Accuracy Score: {:.2f} 1.0
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     26334
#
#     accuracy                           1.00     26334
#    macro avg       1.00      1.00      1.00     26334
# weighted avg       1.00      1.00      1.00     26334
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\millen11\Dropbox\PC\Documents\academia\rpi\classes\fall23\introToML\introToMLapps\project\analysis\find_socioeconomic_solutions.ipynb Cell 15 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> KNN_ru = KNeighborsClassifier().fit(X_train_ru, y_train_ru)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> pred_ru = KNN_ru.predict(X_test_ru)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X24sZmlsZQ%3D%3D?line=7'>8</a> print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a> print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
DT_covid = DecisionTreeClassifier().fit(X_train_covid, y_train_covid)
pred_covid = DT_covid.predict(X_test_covid)

DT_ru = DecisionTreeClassifier().fit(X_train_ru, y_train_ru)
pred_ru = DT_ru.predict(X_test_ru)

print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
# Out:
# Accuracy Score: {:.2f} 1.0
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     26334
#
#     accuracy                           1.00     26334
#    macro avg       1.00      1.00      1.00     26334
# weighted avg       1.00      1.00      1.00     26334
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\millen11\Dropbox\PC\Documents\academia\rpi\classes\fall23\introToML\introToMLapps\project\analysis\find_socioeconomic_solutions.ipynb Cell 16 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X25sZmlsZQ%3D%3D?line=3'>4</a> DT_ru = DecisionTreeClassifier().fit(X_train_ru, y_train_ru)
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> pred_ru = DT_ru.predict(X_test_ru)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a> print("COVID: \n" + evaluate_model(y_test_covid, pred_covid))
#       <a href='vscode-notebook-cell:/c%3A/Users/millen11/Dropbox/PC/Documents/academia/rpi/classes/fall23/introToML/introToMLapps/project/analysis/find_socioeconomic_solutions.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> print("Russia-Ukraine War: \n" + evaluate_model(y_test_ru, pred_ru))
#
# TypeError: can only concatenate str (not "NoneType") to str
