# %%
# import helper
import pandas as pd
import matplotlib as mplt
import numpy as np
import seaborn as sb
import sklearn as skl
import yfinance as yf

# %%
gscpi_index_df = pd.read_csv("C:\\Users\\millen11\\Dropbox\\PC\\Documents\\academia\\rpi\\classes\\fall23\\introToML\\introToMLapps\\project\\dataset\\gscpi_data.csv")
display(gscpi_index_df)

world_indices_page = pd.read_html("https://finance.yahoo.com/world-indices/")
world_indices = world_indices_page[0]
market_indices = {}
for index in world_indices.Symbol:
  market_index_df = helper.create_market_data(index)
  market_indices[index] = market_index_df
print(market_indices)
# Out:
#             Date  GSCPI  Unnamed: 2                           Unnamed: 3
# 0            NaN    NaN         NaN      NEW YORK FED  ECONOMIC RESEARCH  \
# 1            NaN    NaN         NaN                                  NaN
# 2            NaN    NaN         NaN  https://www.newyorkfed.org/research
# 3            NaN    NaN         NaN                                  NaN
# 4    31-Jan-1998  -0.93         NaN                                  NaN
# ..           ...    ...         ...                                  ...
# 308  31-May-2023  -1.57         NaN                                  NaN
# 309  30-Jun-2023  -1.11         NaN                                  NaN
# 310  31-Jul-2023  -0.86         NaN                                  NaN
# 311  31-Aug-2023  -1.08         NaN                                  NaN
# 312  30-Sep-2023  -0.69         NaN                                  NaN
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# ...

# %%
ecpi_m_df = pd.read_csv("C:\\Users\\millen11\\Dropbox\\PC\\Documents\\academia\\rpi\\classes\\fall23\\introToML\\introToMLapps\\project\\dataset\\ecpi_montly.csv")
display(ecpi_m_df)
# Out:
#                                           Country Code  IMF Country Code
# 0                                                  ABW             314.0  \
# 1                                                  ALB             914.0
# 2                                                  ARE             466.0
# 3                                                  ARG             213.0
# 4                                                  ARM             911.0
# ..                                                 ...               ...
# 200                                                ZWE             698.0
# 201                                                NaN               NaN
# 202  Note:  "CPI" indicates IMF Consumer Price Inde...               NaN
# 203                                                NaN               NaN
# 204                                                NaN               NaN
#
#                   Country Indicator Type         Series Name  197001  197002
# ...

# %%
ccpi_m_df = pd.read_csv("C:\\Users\\millen11\\Dropbox\\PC\\Documents\\academia\\rpi\\classes\\fall23\\introToML\\introToMLapps\\project\\dataset\\ccpi_monthly.csv")
display(ccpi_m_df)
# Out:
#     Country Code  IMF Country Code   Country Indicator Type
# 0            ALB             914.0   Albania          Index  \
# 1            AUT             122.0   Austria          Index
# 2            BEL             124.0   Belgium          Index
# 3            BGR             918.0  Bulgaria          Index
# 4            BLR             913.0   Belarus          Index
# ..           ...               ...       ...            ...
# 100          NaN               NaN       NaN            NaN
# 101          NaN               NaN       NaN            NaN
# 102          NaN               NaN       NaN            NaN
# 103          NaN               NaN       NaN            NaN
# 104          NaN               NaN       NaN            NaN
#
#                             Series Name  197001  197002  197003  197004
# 0    Official Core Consumer Price Index     NaN     NaN     NaN     NaN  \
# 1    Official Core Consumer Price Index    21.1    21.2    21.3    21.4
# ...

# %%
epsi_y_df = pd.read_csv("C:\\Users\\millen11\\Dropbox\\PC\\Documents\\academia\\rpi\\classes\\fall23\\introToML\\introToMLapps\\project\\dataset\\epsi.csv")
epsi_y_df = epsi_y_df.drop(columns = ["VAR","Variable","YEA","Unit Code", "Unit","PowerCode Code","PowerCode", "Reference Period Code", "Reference Period","Flag Codes", "Flags"])
display(epsi_y_df)
print(len(epsi_y_df["Country"].unique()))
print(len(ccpi_m_df["Country"].unique()))
# Out:
#        COU       Country  Year  Value
# 0      GRC        Greece  1990    1.0
# 1      GRC        Greece  1991    1.0
# 2      GRC        Greece  1992    1.0
# 3      GRC        Greece  1993    1.0
# 4      GRC        Greece  1994    1.0
# ...    ...           ...   ...    ...
# 17386  ZAF  South Africa  2016    0.0
# 17387  ZAF  South Africa  2017    0.0
# 17388  ZAF  South Africa  2018    0.0
# 17389  ZAF  South Africa  2019    0.0
# 17390  ZAF  South Africa  2020    0.0
#
# [17391 rows x 4 columns]
# 33
# 84

# %%
# high_impact_times = helper.get_impactful_events()
